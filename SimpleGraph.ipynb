# %% [markdown]
# <a href="https://colab.research.google.com/github/AljSese/DATANVI/blob/main/SimpleGraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt

x = [25,49,32,4,13]
y = [8,5,3,7,2]

plt.plot(x, y, marker = 'o', linestyle = '-', color = 'b', label = 'Sample Data')
plt.legend()

plt.grid(True)
plt.show()
